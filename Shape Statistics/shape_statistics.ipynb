# %%
# Elyes Lounissi

import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('lena_256.png', cv2.IMREAD_GRAYSCALE)

# Display the image
plt.imshow(image, cmap='gray')
plt.title('Image')
plt.axis('off')
plt.show()

# %%
# Calculate statistical properties
mean, stddev = cv2.meanStdDev(image)
mean = mean[0][0]
stddev = stddev[0][0]

# Calculate image moments
moments = cv2.moments(image)

# Calculate Hu's moments
hu_moments = cv2.HuMoments(moments).flatten()

print(f"Mean: {mean}")
print(f"Standard Deviation: {stddev}")
print(f"Moments: {moments}")
print(f"Hu Moments: {hu_moments}")
# Out:
# Mean: 123.68373107910156
# Standard Deviation: 48.403726206398716
# Moments: {'m00': 8105737.0, 'm10': 1078198696.0, 'm01': 1001082151.0, 'm20': 187126463450.0, 'm11': 135837000073.0, 'm02': 167612637489.0, 'm30': 36067400224846.0, 'm21': 23912733854467.0, 'm12': 22870084658819.0, 'm03': 31812287247001.0, 'mu20': 43707989836.052185, 'mu11': 2676317731.9525204, 'mu02': 43976073281.35461, 'mu30': -451340041573.5893, 'mu21': 90079959220.37651, 'mu12': -86267736710.9128, 'mu03': 249291341960.4617, 'nu20': 0.0006652361118112109, 'nu11': 4.073358689460842e-05, 'nu02': 0.0006693163449553771, 'nu30': -2.4128070516120574e-06, 'nu21': 4.815561235339977e-07, 'nu12': -4.61176461846816e-07, 'nu03': 1.3326801355601944e-06}
# Hu Moments: [ 1.33455246e-03  6.65354871e-09  1.07195388e-12  1.15512344e-11
#  -4.10366274e-25 -8.69825490e-16  4.06451297e-23]
